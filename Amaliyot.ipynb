# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulazizkomilov/Data-Science/blob/main/Amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)

# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
#
# # 3-MODUL: MA’LUMOTLARGA ISHLOV BERISH. UYG’UNLASHTIRISH, ULASH VA QAYTA SHAKLLASH
#
# ## AMALIYOT

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Ma'lumotlar to'plamini yuklab olish

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Unpacking objects: 100% (60/60), done.

# %% [markdown]
# ## Ma'lumolar to'plami 5 ta csv fayllardan iborat. Har bir fayl nomidagi yillar uchun ma'lumotlarni o'zida saqlaydi. Masalan `2015.csv` faylining ichida 2015 yilda dunyo mamlakatlarining baxtlilik darajalari keltirilgan ma'lumotlarni o'z ichiga oladi va h.k.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Barcha ma'lumotlar to'plamini o'zgaruvchilarga biriktirib olish

# %%
# Ma'lumotlarni (data15, data16, data17, data18, data19) o'zgaruvchilariga biriktirib o'qib oling
# yordam: pd.read_csv dan foydalaning
# Javobni shu yerga yozing
data15 = pd.read_csv('/content/Practicum_Datasets/Happiness/2015.csv')
data16 = pd.read_csv('/content/Practicum_Datasets/Happiness/2016.csv')
data17 = pd.read_csv('/content/Practicum_Datasets/Happiness/2017.csv')
data18 = pd.read_csv('/content/Practicum_Datasets/Happiness/2018.csv')
data19 = pd.read_csv('/content/Practicum_Datasets/Happiness/2019.csv')

# %%
#@title **To'g'ri javob <--> Bizning javob**
years = ['2015', '2016', '2017', '2018', '2019']
data15, data16, data17, data18, data19 = [pd.read_csv(f'./Practicum_Datasets/Happiness/{year}.csv') for year in years]

# %% [markdown]
# ## Ma'lumotlar to'plamini kuzatish

# %% [markdown]
# ## `data15`

# %%
data15.head()
# Out:
#        Country          Region  ...  Generosity  Dystopia Residual
# 0  Switzerland  Western Europe  ...     0.29678            2.51738
# 1      Iceland  Western Europe  ...     0.43630            2.70201
# 2      Denmark  Western Europe  ...     0.34139            2.49204
# 3       Norway  Western Europe  ...     0.34699            2.46531
# 4       Canada   North America  ...     0.45811            2.45176
#
# [5 rows x 12 columns]

# %% [markdown]
# ## `data16`

# %%
data16.head()
# Out:
#        Country          Region  ...  Generosity  Dystopia Residual
# 0      Denmark  Western Europe  ...     0.36171            2.73939
# 1  Switzerland  Western Europe  ...     0.28083            2.69463
# 2      Iceland  Western Europe  ...     0.47678            2.83137
# 3       Norway  Western Europe  ...     0.37895            2.66465
# 4      Finland  Western Europe  ...     0.25492            2.82596
#
# [5 rows x 13 columns]

# %% [markdown]
# ## `data17`

# %%
data17.head()
# Out:
#        Country  ...  Dystopia.Residual
# 0       Norway  ...           2.277027
# 1      Denmark  ...           2.313707
# 2      Iceland  ...           2.322715
# 3  Switzerland  ...           2.276716
# 4      Finland  ...           2.430182
#
# [5 rows x 12 columns]

# %% [markdown]
# ## `data18`

# %%
data18.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.202                      0.393
# 1             2            Norway  ...       0.286                      0.340
# 2             3           Denmark  ...       0.284                      0.408
# 3             4           Iceland  ...       0.353                      0.138
# 4             5       Switzerland  ...       0.256                      0.357
#
# [5 rows x 9 columns]

# %% [markdown]
# ## `data19`

# %%
data19.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %% [markdown]
# ## 1- Topshiriq
# ## Irarxik indeks: 2015 va 2016 yillarga tegishli ma'lumotlar to'plamlarini `Region` va `Country` ustunlarini irarxik ustun ko'rinishiga keltiring va ularning indekslarini tekshiring.

# %%
# Javobni shu yerga yozing (o'zgaruvchilarni data15_mod va data16_mod deb nomlab oling)
# yordam: .set_index() dan foydlanishingiz mumkin
data15_mod = data15.set_index(['Region', 'Country'])
data16_mod = data16.set_index(['Region', 'Country'])
data16_mod
# Out:
#                                              Happiness Rank  Happiness Score  \
# Region                          Country
# Western Europe                  Denmark                   1            7.526
#                                 Switzerland               2            7.509
#                                 Iceland                   3            7.501
#                                 Norway                    4            7.498
#                                 Finland                   5            7.413
# ...                                                     ...              ...
# Sub-Saharan Africa              Benin                   153            3.484
# Southern Asia                   Afghanistan             154            3.360
# Sub-Saharan Africa              Togo                    155            3.303
# Middle East and Northern Africa Syria                   156            3.069
# Sub-Saharan Africa              Burundi                 157            2.905
#
#                                              Lower Confidence Interval  \
# Region                          Country
# Western Europe                  Denmark                          7.460
#                                 Switzerland                      7.428
#                                 Iceland                          7.333
#                                 Norway                           7.421
#                                 Finland                          7.351
# ...                                                                ...
# Sub-Saharan Africa              Benin                            3.404
# Southern Asia                   Afghanistan                      3.288
# Sub-Saharan Africa              Togo                             3.192
# Middle East and Northern Africa Syria                            2.936
# Sub-Saharan Africa              Burundi                          2.732
#
#                                              Upper Confidence Interval  \
# Region                          Country
# Western Europe                  Denmark                          7.592
#                                 Switzerland                      7.590
#                                 Iceland                          7.669
#                                 Norway                           7.575
#                                 Finland                          7.475
# ...                                                                ...
# Sub-Saharan Africa              Benin                            3.564
# Southern Asia                   Afghanistan                      3.432
# Sub-Saharan Africa              Togo                             3.414
# Middle East and Northern Africa Syria                            3.202
# Sub-Saharan Africa              Burundi                          3.078
#
#                                              Economy (GDP per Capita)  \
# Region                          Country
# Western Europe                  Denmark                       1.44178
#                                 Switzerland                   1.52733
#                                 Iceland                       1.42666
#                                 Norway                        1.57744
#                                 Finland                       1.40598
# ...                                                               ...
# Sub-Saharan Africa              Benin                         0.39499
# Southern Asia                   Afghanistan                   0.38227
# Sub-Saharan Africa              Togo                          0.28123
# Middle East and Northern Africa Syria                         0.74719
# Sub-Saharan Africa              Burundi                       0.06831
#
#                                               Family  \
# Region                          Country
# Western Europe                  Denmark      1.16374
#                                 Switzerland  1.14524
#                                 Iceland      1.18326
#                                 Norway       1.12690
#                                 Finland      1.13464
# ...                                              ...
# Sub-Saharan Africa              Benin        0.10419
# Southern Asia                   Afghanistan  0.11037
# Sub-Saharan Africa              Togo         0.00000
# Middle East and Northern Africa Syria        0.14866
# Sub-Saharan Africa              Burundi      0.23442
#
#                                              Health (Life Expectancy)  \
# Region                          Country
# Western Europe                  Denmark                       0.79504
#                                 Switzerland                   0.86303
#                                 Iceland                       0.86733
#                                 Norway                        0.79579
#                                 Finland                       0.81091
# ...                                                               ...
# Sub-Saharan Africa              Benin                         0.21028
# Southern Asia                   Afghanistan                   0.17344
# Sub-Saharan Africa              Togo                          0.24811
# Middle East and Northern Africa Syria                         0.62994
# Sub-Saharan Africa              Burundi                       0.15747
#
#                                              Freedom  \
# Region                          Country
# Western Europe                  Denmark      0.57941
#                                 Switzerland  0.58557
#                                 Iceland      0.56624
#                                 Norway       0.59609
#                                 Finland      0.57104
# ...                                              ...
# Sub-Saharan Africa              Benin        0.39747
# Southern Asia                   Afghanistan  0.16430
# Sub-Saharan Africa              Togo         0.34678
# Middle East and Northern Africa Syria        0.06912
# Sub-Saharan Africa              Burundi      0.04320
#
#                                              Trust (Government Corruption)  \
# Region                          Country
# Western Europe                  Denmark                            0.44453
#                                 Switzerland                        0.41203
#                                 Iceland                            0.14975
#                                 Norway                             0.35776
#                                 Finland                            0.41004
# ...                                                                    ...
# Sub-Saharan Africa              Benin                              0.06681
# Southern Asia                   Afghanistan                        0.07112
# Sub-Saharan Africa              Togo                               0.11587
# Middle East and Northern Africa Syria                              0.17233
# Sub-Saharan Africa              Burundi                            0.09419
#
#                                              Generosity  Dystopia Residual
# Region                          Country
# Western Europe                  Denmark         0.36171            2.73939
#                                 Switzerland     0.28083            2.69463
#                                 Iceland         0.47678            2.83137
#                                 Norway          0.37895            2.66465
#                                 Finland         0.25492            2.82596
# ...                                                 ...                ...
# Sub-Saharan Africa              Benin           0.20180            2.10812
# Southern Asia                   Afghanistan     0.31268            2.14558
# Sub-Saharan Africa              Togo            0.17517            2.13540
# Middle East and Northern Africa Syria           0.48397            0.81789
# Sub-Saharan Africa              Burundi         0.20290            2.10404
#
# [157 rows x 11 columns]

# %%
#@title **To'g'ri javob <--> Bizning javob**
data15_mod = data15.set_index(['Region', 'Country'])
data16_mod = data16.set_index(['Region', 'Country'])
print(f"2015 yil ma'lumolar to'plami\n {data15_mod.index}\n")
print(f"2016 yil ma'lumolar to'plami\n {data16_mod.index}")
# Out:
# 2015 yil ma'lumolar to'plami
#  MultiIndex([(                 'Western Europe',  'Switzerland'),
#             (                 'Western Europe',      'Iceland'),
#             (                 'Western Europe',      'Denmark'),
#             (                 'Western Europe',       'Norway'),
#             (                  'North America',       'Canada'),
#             (                 'Western Europe',      'Finland'),
#             (                 'Western Europe',  'Netherlands'),
#             (                 'Western Europe',       'Sweden'),
#             (      'Australia and New Zealand',  'New Zealand'),
#             (      'Australia and New Zealand',    'Australia'),
#             ...
#             (             'Sub-Saharan Africa',         'Chad'),
#             (             'Sub-Saharan Africa',       'Guinea'),
#             (             'Sub-Saharan Africa',  'Ivory Coast'),
#             (             'Sub-Saharan Africa', 'Burkina Faso'),
#             (                  'Southern Asia',  'Afghanistan'),
#             (             'Sub-Saharan Africa',       'Rwanda'),
#             (             'Sub-Saharan Africa',        'Benin'),
#             ('Middle East and Northern Africa',        'Syria'),
#             (             'Sub-Saharan Africa',      'Burundi'),
#             (             'Sub-Saharan Africa',         'Togo')],
#            names=['Region', 'Country'], length=158)
#
# 2016 yil ma'lumolar to'plami
#  MultiIndex([(                 'Western Europe',     'Denmark'),
#             (                 'Western Europe', 'Switzerland'),
#             (                 'Western Europe',     'Iceland'),
#             (                 'Western Europe',      'Norway'),
#             (                 'Western Europe',     'Finland'),
#             (                  'North America',      'Canada'),
#             (                 'Western Europe', 'Netherlands'),
#             (      'Australia and New Zealand', 'New Zealand'),
#             (      'Australia and New Zealand',   'Australia'),
#             (                 'Western Europe',      'Sweden'),
#             ...
#             (             'Sub-Saharan Africa',  'Madagascar'),
#             (             'Sub-Saharan Africa',    'Tanzania'),
#             (             'Sub-Saharan Africa',     'Liberia'),
#             (             'Sub-Saharan Africa',      'Guinea'),
#             (             'Sub-Saharan Africa',      'Rwanda'),
#             (             'Sub-Saharan Africa',       'Benin'),
#             (                  'Southern Asia', 'Afghanistan'),
#             (             'Sub-Saharan Africa',        'Togo'),
#             ('Middle East and Northern Africa',       'Syria'),
#             (             'Sub-Saharan Africa',     'Burundi')],
#            names=['Region', 'Country'], length=157)

# %%
data15_mod.head()
# Out:
#                             Happiness Rank  ...  Dystopia Residual
# Region         Country                      ...
# Western Europe Switzerland               1  ...            2.51738
#                Iceland                   2  ...            2.70201
#                Denmark                   3  ...            2.49204
#                Norway                    4  ...            2.46531
# North America  Canada                    5  ...            2.45176
#
# [5 rows x 10 columns]

# %%
data16_mod.head()
# Out:
#                             Happiness Rank  ...  Dystopia Residual
# Region         Country                      ...
# Western Europe Denmark                   1  ...            2.73939
#                Switzerland               2  ...            2.69463
#                Iceland                   3  ...            2.83137
#                Norway                    4  ...            2.66465
#                Finland                   5  ...            2.82596
#
# [5 rows x 11 columns]

# %% [markdown]
# ## 2- Topshiriq
# ## **Vazifa**: Yuqorida ajratib olingan ma'lumotlar to'plamidan `Western Europe` hududiga kiruvchi mamlakatlarning har ikkala yillar uchun ma'lumotlarini ajratib oling.

# %%
# Javobni shu yerga yozing (we_2015, we_2016 o'zgaruvchilaridan foydalaning)
data15_mod.loc['Western Europe']
data16_mod.loc['Western Europe']
# Out:
#                 Happiness Rank  Happiness Score  Lower Confidence Interval  \
# Country
# Denmark                      1            7.526                      7.460
# Switzerland                  2            7.509                      7.428
# Iceland                      3            7.501                      7.333
# Norway                       4            7.498                      7.421
# Finland                      5            7.413                      7.351
# Netherlands                  7            7.339                      7.284
# Sweden                      10            7.291                      7.227
# Austria                     12            7.119                      7.045
# Germany                     16            6.994                      6.930
# Belgium                     18            6.929                      6.861
# Ireland                     19            6.907                      6.836
# Luxembourg                  20            6.871                      6.804
# United Kingdom              23            6.725                      6.647
# Malta                       30            6.488                      6.409
# France                      32            6.478                      6.397
# Spain                       37            6.361                      6.288
# Italy                       50            5.977                      5.898
# North Cyprus                62            5.771                      5.670
# Cyprus                      69            5.546                      5.442
# Portugal                    94            5.123                      5.030
# Greece                      99            5.033                      4.935
#
#                 Upper Confidence Interval  Economy (GDP per Capita)   Family  \
# Country
# Denmark                             7.592                   1.44178  1.16374
# Switzerland                         7.590                   1.52733  1.14524
# Iceland                             7.669                   1.42666  1.18326
# Norway                              7.575                   1.57744  1.12690
# Finland                             7.475                   1.40598  1.13464
# Netherlands                         7.394                   1.46468  1.02912
# Sweden                              7.355                   1.45181  1.08764
# Austria                             7.193                   1.45038  1.08383
# Germany                             7.058                   1.44787  1.09774
# Belgium                             6.997                   1.42539  1.05249
# Ireland                             6.978                   1.48341  1.16157
# Luxembourg                          6.938                   1.69752  1.03999
# United Kingdom                      6.803                   1.40283  1.08672
# Malta                               6.567                   1.30782  1.09879
# France                              6.559                   1.39488  1.00508
# Spain                               6.434                   1.34253  1.12945
# Italy                               6.056                   1.35495  1.04167
# North Cyprus                        5.872                   1.31141  0.81826
# Cyprus                              5.650                   1.31857  0.70697
# Portugal                            5.216                   1.27607  0.94367
# Greece                              5.131                   1.24886  0.75473
#
#                 Health (Life Expectancy)  Freedom  \
# Country
# Denmark                          0.79504  0.57941
# Switzerland                      0.86303  0.58557
# Iceland                          0.86733  0.56624
# Norway                           0.79579  0.59609
# Finland                          0.81091  0.57104
# Netherlands                      0.81231  0.55211
# Sweden                           0.83121  0.58218
# Austria                          0.80565  0.54355
# Germany                          0.81487  0.53466
# Belgium                          0.81959  0.51354
# Ireland                          0.81455  0.54008
# Luxembourg                       0.84542  0.54870
# United Kingdom                   0.80991  0.50036
# Malta                            0.80315  0.54994
# France                           0.83795  0.46562
# Spain                            0.87896  0.37545
# Italy                            0.85102  0.18827
# North Cyprus                     0.84142  0.43596
# Cyprus                           0.84880  0.29507
# Portugal                         0.79363  0.44727
# Greece                           0.80029  0.05822
#
#                 Trust (Government Corruption)  Generosity  Dystopia Residual
# Country
# Denmark                               0.44453     0.36171            2.73939
# Switzerland                           0.41203     0.28083            2.69463
# Iceland                               0.14975     0.47678            2.83137
# Norway                                0.35776     0.37895            2.66465
# Finland                               0.41004     0.25492            2.82596
# Netherlands                           0.29927     0.47416            2.70749
# Sweden                                0.40867     0.38254            2.54734
# Austria                               0.21348     0.32865            2.69343
# Germany                               0.28551     0.30452            2.50931
# Belgium                               0.26248     0.24240            2.61355
# Ireland                               0.29754     0.44963            2.15988
# Luxembourg                            0.35329     0.27571            2.11055
# United Kingdom                        0.27399     0.50156            2.14999
# Malta                                 0.17554     0.56237            1.99032
# France                                0.17808     0.12160            2.47440
# Spain                                 0.06137     0.17665            2.39663
# Italy                                 0.02556     0.16684            2.34918
# North Cyprus                          0.16578     0.26322            1.93447
# Cyprus                                0.05228     0.27906            2.04497
# Portugal                              0.01521     0.11691            1.53015
# Greece                                0.04127     0.00000            2.12944

# %%
#@title **To'g'ri javob <--> Bizning javob**
we_2015 = data15_mod.loc['Western Europe']
we_2016 = data16_mod.loc['Western Europe']

# %%
data15_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 158 entries, ('Western Europe', 'Switzerland') to ('Sub-Saharan Africa', 'Togo')
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Rank                 158 non-null    int64
#  1   Happiness Score                158 non-null    float64
#  2   Standard Error                 158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 18.6+ KB

# %% [markdown]
# ## 3-Topshiriq
#
# ### Barcha ma'lumotlar to'plamini kuzatgan bo'lsangiz, ba'zilarining ustunlari o'zgarib kelmoqda. Lekin bu bizga qiziq emas. Biz asosiy maqsadni ushbu ma'lumotlardan faqat mamlakatlarning baxtlilik darajalarinigina ajratib olishga qaratamiz.
#
# ### **Vazifa**: Barcha ma'lumotlar to'plamlaridan faqat mamalakatlar (`Country` yoki `Country or region`), ularning baxtlilik darajasini (`Happiness Rank`, `Happiness.Rank` yoki `Overall rank`) va baholarini (`Happiness Score`, `Happiness.Score` yoki `Score`)  ajratib oling.

# %%
# Javobni shuyerga yozing
w_data15 = data15_mod[['Happiness Rank','Happiness Score']]
w_data15
# Out:
#                                              Happiness Rank  Happiness Score
# Region                          Country
# Western Europe                  Switzerland               1            7.587
#                                 Iceland                   2            7.561
#                                 Denmark                   3            7.527
#                                 Norway                    4            7.522
# North America                   Canada                    5            7.427
# ...                                                     ...              ...
# Sub-Saharan Africa              Rwanda                  154            3.465
#                                 Benin                   155            3.340
# Middle East and Northern Africa Syria                   156            3.006
# Sub-Saharan Africa              Burundi                 157            2.905
#                                 Togo                    158            2.839
#
# [158 rows x 2 columns]

# %%
#@title **To'g'ri javob <--> Bizning javob**

def extractor(dataframe):
  """Ma'lumotlar to'plamidan faqat bizga kerakli ustunlarga tegishli 
     ma'lumotlarni ajratib olguvchi funksiya
  """
  columns = ['Country', 'Country or region', 'Happiness Rank', 'Happiness.Rank','Overall rank', 'Happiness Score','Happiness.Score', 'Score']
  mask = [col for col in dataframe.columns if col in columns]
  return dataframe[mask]

dataframes = [data15, data16, data17, data18, data19] 
data15, data16, data17, data18, data19 = [extractor(dataframe) for dataframe in dataframes]

# %% [markdown]
# ## Vazifa: Ma'lumotlarni ajratib olgan bo'lsangiz, unda e'tibor bering ba'zi yillardagi ma'lumotlarning ustunlari bir biridan farq qiladi. `Ana endi bularning barchasini bir xil formatga keltirib olishimiz kerak.` (`data_15, data_16` larning ustunlaridek formatiga keltirib oling: Ya'ni `Country`, `Happiness Rank` va `Happiness Score` ketma-ketligida)

# %%
columns = ['Country', 'Happiness Rank', 'Happiness Score']

data17.columns = columns

data18 = data18[['Country or region', 'Overall rank', 'Score']]
data18.columns = columns

data19 = data19[['Country or region', 'Overall rank', 'Score']]
data19.columns = columns

# %%
#@title **To'g'ri javob <--> Bizning javob**
columns = ['Country', 'Happiness Rank', 'Happiness Score']

data17.columns = columns # data17 ning tartibi mos keladi

data18 = data18[['Country or region', 'Overall rank', 'Score']] # data18 ning tartibini moslab olish
data18.columns = columns

data19 = data19[['Country or region', 'Overall rank', 'Score']] # data19 ning tartibini moslab olish
data19.columns = columns

# %% [markdown]
# ## 4-Topshiriq
#
# ## Navbatdagi mashqimiz irarxik ustunlar haqida bo'ladi.
#
# ## **Vazifa**: Barcha ma'lumotlar to'plamini ustunlarini irarxik ko'rinishga keltirish kerak. Quyidagi rasmda `2015` yil uchun qanday ko'rinishda bo'lishi ko'rsatilgan. Qolganlarini mustaqil bajaring.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Javobni shu yerga yozing. 
# Yordam: Irarxik ustunlar haqidagi video darslikga murojat qiling
data15 = pd.DataFrame(data15.values, index=data15.index, columns=[[2015, 2015, 2015], ['Country', 'Happiness Rank', 'Happiness Score']])
data16 = pd.DataFrame(data16.values, index=data16.index, columns=[[2016, 2016, 2016], ['Country', 'Happiness Rank', 'Happiness Score']])
data17 = pd.DataFrame(data17.values, index=data17.index, columns=[[2017, 2017, 2017], ['Country', 'Happiness Rank', 'Happiness Score']])
data18 = pd.DataFrame(data18.values, index=data18.index, columns=[[2018, 2018, 2018], ['Country', 'Happiness Rank', 'Happiness Score']])
data19 = pd.DataFrame(data19.values, index=data19.index, columns=[[2019, 2019, 2019], ['Country', 'Happiness Rank', 'Happiness Score']])

# %% [markdown]
# ## 5-Topshiriq
#
# ## Barcha ma'lumotlarni irarxik ustunlar ko'rinishiga keltirib olgan bo'lsangiz, unda navbatdagi mashqimizda ularni birlashtiramiz.
#
# ## **Vazifa:** Gorizantal o'q ko'rinishida barcha ma'lumotlar to'plamlarini birlashtiring (`axis=1`). Va natijaviy dataframe ustunlariga `Years` va `Info` deb nom bering.
#
# ## `Natijangiz quyidagi rasm ko'rinishida bo'lsin.`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Javobni shu yerga yozing.
# Yordam: .concat() usulida foydalaning.
dataframes = [data15, data16, data17, data18, data19] 
data = pd.concat([data15, data16, data17, data18, data19], axis=1)
data.columns.names = ['Years', 'Info']
data
# Out:
# Years         2015                                        2016                 \
# Info       Country Happiness Rank Happiness Score      Country Happiness Rank
# 0      Switzerland              1           7.587      Denmark              1
# 1          Iceland              2           7.561  Switzerland              2
# 2          Denmark              3           7.527      Iceland              3
# 3           Norway              4           7.522       Norway              4
# 4           Canada              5           7.427      Finland              5
# ..             ...            ...             ...          ...            ...
# 153         Rwanda            154           3.465  Afghanistan            154
# 154          Benin            155            3.34         Togo            155
# 155          Syria            156           3.006        Syria            156
# 156        Burundi            157           2.905      Burundi            157
# 157           Togo            158           2.839          NaN            NaN
#
# Years                                      2017                 \
# Info  Happiness Score                   Country Happiness Rank
# 0               7.526                    Norway              1
# 1               7.509                   Denmark              2
# 2               7.501                   Iceland              3
# 3               7.498               Switzerland              4
# 4               7.413                   Finland              5
# ..                ...                       ...            ...
# 153              3.36                   Burundi            154
# 154             3.303  Central African Republic            155
# 155             3.069                       NaN            NaN
# 156             2.905                       NaN            NaN
# 157               NaN                       NaN            NaN
#
# Years                                      2018                 \
# Info  Happiness Score                   Country Happiness Rank
# 0               7.537                   Finland              1
# 1               7.522                    Norway              2
# 2               7.504                   Denmark              3
# 3               7.494                   Iceland              4
# 4               7.469               Switzerland              5
# ..                ...                       ...            ...
# 153             2.905               South Sudan            154
# 154             2.693  Central African Republic            155
# 155               NaN                   Burundi            156
# 156               NaN                       NaN            NaN
# 157               NaN                       NaN            NaN
#
# Years                                      2019
# Info  Happiness Score                   Country Happiness Rank Happiness Score
# 0               7.632                   Finland              1           7.769
# 1               7.594                   Denmark              2             7.6
# 2               7.555                    Norway              3           7.554
# 3               7.495                   Iceland              4           7.494
# 4               7.487               Netherlands              5           7.488
# ..                ...                       ...            ...             ...
# 153             3.254               Afghanistan            154           3.203
# 154             3.083  Central African Republic            155           3.083
# 155             2.905               South Sudan            156           2.853
# 156               NaN                       NaN            NaN             NaN
# 157               NaN                       NaN            NaN             NaN
#
# [158 rows x 15 columns]
